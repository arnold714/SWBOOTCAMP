# %%
import requests
import sqlite3

con = sqlite3.connect("t1.db")
cur = con.cursor()

keys = []
columns = []

base_url = "https://graph.facebook.com/v17.0/17841401909127496"

# Access Token
access_token = "EAAIoEknsW6cBO3jSBlrOQeNXnpl0z3PYsR4p4lu9F91ZBVPGLuGjHwGmZAprQeNzND9UbUE1eOKGjZCFYMNygfw3KJMi4DVsUSmMAh7FHOsoonuzijl9GWZA8ZA8pvWzj5ndGj7bXNZB4SDDE0qjBw0F83VZAr0dL1ZAfhXHmgr0AZAPEVwZC5mZAZCd0HZC3"

# Parameters for profile information
profile_params = {
    "fields": "business_discovery.username(b.saem){biography,name,username,follows_count,website,ig_id,followers_count,media_count}",
    "access_token": access_token,
    "limit": 10
}


# Fetching profile information
profile_response = requests.get(base_url, params=profile_params)
if profile_response.status_code == 200:
    profile_data = profile_response.json()
    profile_info = profile_data['business_discovery']

    print("사용자 정보:")
    print(f"ID: {profile_info['ig_id']}")
    print(f"사용자명: {profile_info['username']}")
    print(f"소개글: {profile_info['biography']}")
    print(f"미디어 수: {profile_info['media_count']}")
    print(f"팔로우 수: {profile_info['follows_count']}")
    print(f"팔로워 수: {profile_info['followers_count']}")
    keys = [(profile_info['ig_id']),(profile_info['username']),(profile_info['biography']),(profile_info['media_count']),(profile_info['follows_count']),(profile_info['followers_count'])]
    cur.execute("INSERT INTO influencers VALUES (?,?,?,?,?,?)", (keys))
    con.commit()
    print("-------------------------------------------------------------------------")
else:
    print(f"Error: {profile_response.status_code}, {profile_response.text}")
# Out:
# 사용자 정보:
# ID: 621573376
# 사용자명: b.saem
# 소개글: 🏷️ 찐추천템 로이드미 드라이기 8.1(화) pm 09:00 open
# DM❌문의는 댓글로 남겨주세요😊
# 미디어 수: 1931
# 팔로우 수: 411
# 팔로워 수: 187268
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[10], line 37
#      35 print(f"팔로워 수: {profile_info['followers_count']}")
#      36 keys = [(profile_info['ig_id']),(profile_info['username']),(profile_info['biography']),(profile_info['media_count']),(profile_info['follows_count']),(profile_info['followers_count'])]
# ---> 37 cur.execute("INSERT INTO influencers VALUES (?,?,?,?,?,?)", (keys))
#      38 con.commit()
#      39 print("-------------------------------------------------------------------------")
#
# OperationalError: no such table: influencers

# %%
feed_params = {
    "fields": "business_discovery.username(b.saem){media{id,caption,comments_count,children{media_type},like_count,media_product_type,timestamp,username,owner}}",
    "access_token": access_token
}
# Fetching feed data without Pagination
feed_response = requests.get(base_url, params=feed_params)
if feed_response.status_code == 200:
    data = feed_response.json()
    media_list = data['business_discovery']['media']['data']
    discovery_list = data['business_discovery']['media']

    print("게시물 정보:")
    for media_data in media_list:
        # 미디어 정보 출력 (기존 코드와 동일)
        print("게시물 ID:", media_data['id'])
        print("캡션:", media_data['caption'])
        print("댓글 수:", media_data['comments_count'])
        like_count = media_data.get('like_count', "비공개")
        print("좋아요 수:", like_count)
        print("미디어 타입:", media_data['media_product_type'])
        print("타임스탬프:", media_data['timestamp'])
        print("사용자명:", media_data['username'])
        owner_id = media_data.get('owner', {}).get('id', None)
        print("사용자 코드:", owner_id)
        columns = [(media_data['id']),(media_data['caption']),(media_data['comments_count']),(like_count),(media_data['media_product_type']),(media_data['timestamp']),(media_data['username']),(owner_id)]
        cur.execute("INSERT INTO influencers_post VALUES (?,?,?,?,?,?,?,?)", (columns))
        con.commit()
        print("-------------------------------------------------------------------------")

    after_token = discovery_list['paging']['cursors']['after']
    print(after_token)


else:
    print(f"Error: {feed_response.status_code}, {feed_response.text}")
# Out:
# 게시물 정보:
# 게시물 ID: 18040324150500385
# 캡션: 🎁알람 댓글 이벤트 있어요🎁
# 여러분 제가 또,,대박템 가지고 왔습니다🙊
# 샤오미의 에코 브랜드인 “로이드미”에서 출시된 요 드라이기!
#
# 이미 집에 다00, jm0의 드라이기가 있지만
# 이 3가지 중에 딱 하나만 선택 하라고 하면
# 저는 망설임 없이 로이드미 드라이기 선택할 거예요😇
#
# 그 동안 다00이 최고라고 생각해서
# 여행 갈 때에도 바리바리 드라이기까지 가지고 가던 사람이 전데요🙋🏻‍♀️
#
# 🎟️ 로이드미 드라이기! 다00 보다 더 좋습니다,,,,🥹
# 크기도 더 컴팩트하고 더 가벼운데, 풍속은 더 세고 소음은 더 조용한 혁명템,,
# 심지어 프리볼트라 해외에서도 돼지코만 있으면 사용 가능해요!
# (참고로 다00은 전압이 다른 곳에서는 사용 불가 합니다.)
#
# 저는 숱많은 긴머리라 머리 말릴 때 무조건 10분 이상은 걸렸는데
# 로이드미는 이걸 5분에 끝냅니다,,
# (남자는 30초-1분컷이에요👨🏻)
# 그리고 머리 말리다가도 드라이기 무거워서 손 내리고 좀 쉬고 그랬는데,
# 로이드미는 정말 가벼워서 손에 무리도 안가더라구요!
#
# 제 머리 뿐만 아니라 초롱이 목욕하고 나서 말리는 시간도
# 1/3로 줄어서 여러모로 삶의 질 쭉쭉 상승시켜주는 아이템이 아닐 수 없어요!
#
# 그냥 예쁘고 빠르게 마르는 드라이기가 아니라
#  2,000만개 음이온 방출로 모발에
# 보호층까지 형성해주는 혁명템입니다💓
#
# 특히 더운 날 드라이 오래하면 땀 나서 뭐 하기도 전에
# 벌써 지치잖아요,,
# 159,000원으로 우리 가족 머리 말리는 시간 사가세요😇
# (거치대는 9,900원 추가 구매)
#
# 아직도 오래된 드라이기, 무거운 드라이기,
# 바람은 쎄지만 머릿결 망가지는 드라이기 쓰고 계신다면
# 👉🏻 로이드미 드라이기 정말정말 강추합니다😆
#
# 𝑹𝒊𝒐𝒅𝒎𝒊 𝑯𝒂𝒓𝒊𝒅𝒓𝒚𝒆𝒓💨
#
# ▸ 105,000rpm 초고속 모터로 스피드한 모발 건조
# ▸ D사보다 빠른 65m/s풍속, 315g의 가벼운 무게!
# ▸ 59.3dB의 저소음 모터
# ▸ 인체 공학에 맞게 설계된 사이즈로 뛰어난 그립감
# ▸ RGB조명으로 쉽게 보는 드라이기 온도 (6단계 모드)
# ▸ 2,000만개 음이온 방출로 모발의 정전기 감소 및 보호층 형성
# ▸ 과열 방지를 위해 단열성을 높이고 과열방지 온도센서 장착
# ▸ 스크래치와 마모에 강한 고급 UV 코팅
# ▸ 오염 방지 및 미끄럼 방지를 해주는 전기 도금 기술
# ▸ 360도 회전 가능한 마그네틱 송풍구
# ▸ 마그네틱 탈부착 커버로 모발 흡입 방지 및 먼지 흡입 방지
# ▸ 간편한 공기 흡입구 청소를 위해 탈부착 가능한 송풍구 필터
# ▸ 프리볼트로 해외에서 사용 가능(변환 플러그 사용)
#
# 🎟️ 로이드미 헤어드라이기는 8월 1일 화요일 오후 9시에 오픈 됩니다!
#
# 🎁 오픈 알람 받고 싶으신 분들은 좋아요+댓글 남겨주세요!
# 좋아요 누르고 알람 댓글 남겨주신 분들 중 3분께 로이드미 드라이기+3종 거치대를 선물로 드려요🤍
# 댓글 수: 447
# 좋아요 수: 비공개
# 미디어 타입: REELS
# 타임스탬프: 2023-07-30T11:07:55+0000
# 사용자명: b.saem
# 사용자 코드: 17841400161289712
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[8], line 26
#      24 print("사용자 코드:", owner_id)
#      25 columns = [(media_data['id']),(media_data['caption']),(media_data['comments_count']),(like_count),(media_data['media_product_type']),(media_data['timestamp']),(media_data['username']),(owner_id)]
# ---> 26 cur.execute("INSERT INTO influencers_post VALUES (?,?,?,?,?,?,?,?)", (columns))
#      27 con.commit()
#      28 print("-------------------------------------------------------------------------")
#
# OperationalError: no such table: influencers_post

# %%
feed_params = {
    "fields": f"business_discovery.username(b.saem){{media.after({after_token}){{id,caption,comments_count,children{{media_type}},like_count,media_product_type,timestamp,username,owner}}}}",
    "access_token": access_token
}

# Fetching feed data without Pagination
feed_response = requests.get(base_url, params=feed_params)
if feed_response.status_code == 200:
    data = feed_response.json()
    media_list = data['business_discovery']['media']['data']
    discovery_list = data['business_discovery']['media']

    print("게시물 정보:")
    for media_data in media_list:
        # 미디어 정보 출력 (기존 코드와 동일)
        print("게시물 ID:", media_data['id'])
        print("캡션:", media_data['caption'])
        print("댓글 수:", media_data['comments_count'])
        like_count = media_data.get('like_count', "비공개")
        print("좋아요 수:", like_count)
        print("미디어 타입:", media_data['media_product_type'])
        print("타임스탬프:", media_data['timestamp'])
        print("사용자명:", media_data['username'])
        owner_id = media_data.get('owner', {}).get('id', None)
        print("사용자 코드:", owner_id)
        columns = [(media_data['id']),(media_data['caption']),(media_data['comments_count']),(like_count),(media_data['media_product_type']),(media_data['timestamp']),(media_data['username']),(owner_id)]
        cur.execute("INSERT INTO influencers_post VALUES (?,?,?,?,?,?,?,?)", (columns))
        con.commit()
        print("-------------------------------------------------------------------------")

    after_token = discovery_list['paging']['cursors']['after']
    print(after_token)

else:
    print(f"Error: {feed_response.status_code}, {feed_response.text}")
# Out:
# 게시물 정보:
# 게시물 ID: 18343324849078611
# 캡션: 이 사진을 보시고 “우와 진짜 깔끔하다,,”라고 생각하시면서
# 이런 옷방은 남의 집 얘기지😂라고 생각하시는 분들☝🏻
# 마와 옷걸이만 있으면 누구나 깔끔한 옷장을 가질 수 있다구요🫢
#
# 저는 그냥 마와 옷걸이에 컬러별로 옷을 정리한 것 밖에는 없는데
# 이 사진 보면 저 집안일 깔끔하게 하는 사람처럼 보이지 않나요,,?😆ㅋㅋㅋ
# 사실 마와가 다 해준건데,,마와 사용하시는 분들은 아시죠🙊
#
# 이왕이면 정리할 때 저처럼 비슷한 컬러로 맞춰서 정리해 보세요!
# 정리 잘 된 옷방만 보면 너무 뿌듯해서 강박적으로 옷방을 정리하게 되는 기이한(?) 현상도 경험하실 수 있습니다 껄껄
# (이렇게 한번 싹 이렇게 깨끗하게 정리해 두면 지저분해져도 금방 다시 정리가 되더라구요!)
#
# 들어갈 때마다 스트레스 받았던 옷 방이라면! 이제 마와가 변화시켜드릴게요🪄
# 자주 마주하는 공간이 깔끔할 수록 나의 행복지수도 쭉쭉 상승합니다🦄
#
# 🌷혹시,,최근에 우울하거나 스트레스 받는 일 많으신 분들 계시다면
# 옷방 한번 뒤집어 보지 않으시겠어요?✊🏻
# 컬러 맞춰서 마와로 옷 하나씩 착착 걸 때마다 묵혔던 속이 뻥 뚫리면서
# 스트레스 날아갑니다,,🤍
# (한번에 뒤집는게 겁나는 분들은 한칸씩이라도 정리해 보세요🙊)
#
# 이번 기획전으로 마와 처음 입문하신 분들은
# 옷 걸어보고 깜짝 놀라서 바로 재구매 중이시구요,,
# 이전에 입문하신 분들은 네,,여전히 재구매 중입니다😇ㅋㅋㅋ
# 그 만큼 한번 써보면 절대 다른 옷걸이로는 못돌아가는 마성의 마와에요☁️
#
# ➡️ 옷걸이만 바꿨을 뿐인데 공간이 더 늘어난다고?
# 마와로 정리하면 40%의 여유공간이 생기는 마법을 경험하실 수 있어요!
#
# 🧶 평소 티셔츠, 니트의 어깨뿔, 넥라인 늘어남이 고민이셨던 분들은
# 어깨라인 넥라인 변형없이 보관 가능한 마와를 사용하셔야 합니다✨
#
# 🍉 가벼워서 살짝만 건드려도 툭툭 떨어지던 여름 옷들!
# 마와는 무독성의 논슬립 재질로 흘러내림 방지 효과가 있습니다🪽
#
# 👖하의류 바지걸이 또한 자국 없이 사용하실 수 있어요!
#
# 👜 이름은 가방걸이 이지만, 모자 / 머플러 / 벨트 등 정리하기 애매한 물건을 깔끔하게 정리 가능한 가방걸이도 무조건 꼭 같이 하셔야 해요🤍
#
# ⏰ 마와 기획전은 내일(금) 자정에 마감됩니다!
# 댓글 수: 46
# 좋아요 수: 667
# 미디어 타입: FEED
# 타임스탬프: 2023-06-29T12:01:17+0000
# 사용자명: b.saem
# 사용자 코드: 17841400161289712
# -------------------------------------------------------------------------
# 게시물 ID: 18116451148308309
# 캡션: 옷걸이계의 끝판왕 마와 옷걸이 진행 중입니다🫶🏻
# 아직도 세탁소 옷걸이 사용하신다면, 아직도 원목 옷걸이를 사용하신다면
# 저 믿고 마와로 한번 바꿔보세요🙊
#
# 1401HOME 홈페이지에만 남겨진 리뷰가 3370여개 되는데,
# 쭉 읽어보면 아시겠지만 대부분의 고객님들이 극찬을 아끼지 않는 제품이 바로 마와에요.
#
# 👉🏻고객님이 남겨주신 후기 중 정말 공감 했던 내용이
# "마와 옷걸이로 공간을 살 수 있어요!!!" 라는 내용이었어요.
# 써 본 분들은 이 문장에 정말 공감하실 거예요.
#
# 사용하기 전에는 다들 반신반의 하다가 "어머 정말 이게 되네" 하게 되는게 바로 마와 옷걸이랍니다🫢
#
# 한번 사용해 보면 재진행 날짜만 손꼽아 기다릴 수 밖에 없을 정도로 중독적인 제품이라
# 마와 기획전은 끝난 직후부터 다음 기획전 전까지 일정 문의가 가장 많은 제품이기도 해요😆
#
# 그럴 수 밖에 없는게 마와로 옷방을 정리하면 티셔츠, 니트에 어깨뿔이 안생기는 건 기본이고, 옷장에 없던 공간이 생기고, 우리집 드레스룸이 의류 매장처럼 깔-꼼해 지니깐 마와 말고 다른 옷걸이에는 옷을 걸고 싶지 않게 되거든요,,💫
#
# 🧶 일반 옷걸이에 아끼는 니트 보관 했다가 입으려고 꺼냈는데,
# 양쪽에 어깨뿔이 툭 튀어나와 있어서 곤란했던 경험 있으시죠?
# 그렇다고 니트를 접어서 보관 하기에는 서랍장 자리를 너무 많이 차지하기도 하고 자국도 남아서 걸어서 보관하는게 가장 좋더라구요🥲
#
# 근데 옷걸이 때문에 한번 늘어나버린 옷은 뭘 해도 완벽하게 처음처럼 돌아오지는 않아요🥹
# 마와는 티셔츠, 니트를 걸어두었을 때 어깨라인이 튀어나오지 않고 그대로 유지되어
# 아끼는 옷을 오래오래 입으실 수 있는 삶의 질 상승템 입니다🪄
#
# 👙마와 옷걸이는 논슬립 처리되어 옷이 흘러내릴 일도 없어요!
# 특히 여름옷들 가벼워서 걸려고 하면 주르륵 흘러내리거나,
# 다른 옷 꺼내려고 살짝만 건드려도 흘러내린 경험 다들 있으시죠?
# 마와 옷걸이로 바꾸면 옷방에서 스트레스 받는 일은 없으실 거예요✊🏻
#
# 🌳 마와는 친환경&무독성 재질의 녹슬지 않는 스테인레스로 제작되어 한 번 사두면 평-생 사용할 수 있는 평생템이니 옷걸이에 괜한 돈 쓴다고 생각하지 마시고, 옷걸이로 내 행복을 산다고 생각하고 구매해 주세요!
# 자주 마주하는 공간이 깔끔하고 정돈되어 있으면 행복지수도 상승한다구요📈
#
# ⚠️ 70년 전통의 오리지널 프리미엄 옷걸이 마와의 모양을 비슷하게 따라한 유사품들이 있지만, 마와를 먼저 사용해 보신 뒤에 유사품을 사용해 보신 분들은 결국 다시 마와로 돌아올 정도로 퀄리티에 있어서 차이가 납니다.
# 마와보다 옷걸이 끝라인이 뻗쳐있고 쉽게 휘어진다고 말씀해 주시더라구요🥺
#
# 🍉 처음 입문하시는 분들은 한 세트만 구매해도 무료배송 적용되니 이코노믹 라이트로 입문해 보시는 것 추천드려요😆
#
# ⏰ 현재 이코노믹 라이트-화이트 컬러는 준비한 수량 절반 정도 소진 되었습니다!
# 항상 제일 먼저 품절되는 옵션이니 구매 원하시는 분들은 서둘러 주세요🏃🏻‍♀️
#
# 📌 어떤 제품을 구매하셔야 하는지 어려우신 경우 가지고 계신 옷의 종류를 말씀해 주세요!
# 댓글로 상담해 드리도록 하겠습니다🤍
#
# 🎪 이전 피드에 “구매완료” 댓글 남겨주시는 분들 중 15분을 추첨하여
# 여름 옷 정리하기 딱 좋은! 이코노믹 라이트 선물로 보내드려요🎁
#
# 🧺독일 프리미엄 마와 옷걸이
# ▸ 티셔츠, 니트 등 어깨라인 변형 없이 보관 가능
# ▸ 논슬립 코팅으로 마감되어 흘러내림 방지 효과
# ▸ 종류별로 의류 특성에 맞게 보관 가능
# ▸ 슬림한 두께로 제작되어 공간을 효율적으로 사용 가능
# ▸ 녹슬지 않는 스테인레스로 제작되어 스팀 및 의류관리기 사용에 적합
# ▸ 360도 돌아가는 훅 (처음엔 조금 단단하게 고정되어 있지만 힘주어 돌리면 돌아갑니다.)
# ▸ 친환경&무독성 소재
# ▸ FSC 인증 국제 친환경 소재 인증
# 댓글 수: 38
# 좋아요 수: 비공개
# 미디어 타입: FEED
# 타임스탬프: 2023-06-28T04:27:08+0000
# 사용자명: b.saem
# 사용자 코드: 17841400161289712
# -------------------------------------------------------------------------
# 게시물 ID: 18013737493716125
# 캡션: 3개월 만에,,,🥹마와 기획전 오픈 했습니다🤍
#
# 🎪 마와 구매 후 해당 피드에 “구매완료” 남겨주시면 15분을 추첨해서
# 여름용 티셔츠 정리하기 딱 좋은 이코노믹 라이트 10개를 선물로 보내드릴게요😆
#
# 영상에서 마와의 놀라운 공간 활용도가 느껴지시나요🙊
# 사실 옷 30벌은 더 걸 수 있는데,,서랍장에 넣어둔 티셔츠들까지 싹 꺼내서 찍을 껄 그랬어요😆
# 옷을 이렇게 많이 걸었는데도 지저분하거나 한 느낌 하나도 없죠!?✨
#
# ⚠️ 영상처럼 마와 옷걸이를 사용하면 옷이 정말 많이 걸려요!
# 장농, 시스템장은 마와를 사용해서 옷을 많이 걸어도 상관 없지만
# 압축봉 헹거를 사용하시는 분들은 헹거 무너짐에 주의하세요,,,
# 옷이 너무 많이 걸려서 계속 걸다보면 헹거가 무너질 수도 있어요🥹
#
# 🏷️ 21년 3월에 1401HOME에서 인스타그램 최초로 시작했던 마와 기획전!
# 오픈 할 때마다 뜨겁게 사랑해 주셔서 벌써 13회차 진행이에요🥳
#
# 한 번 사용해 보면 절대 다른 옷걸이로는 못돌아가는 마성의 옷걸이라서
# 진행 할 때마다 늘어나는 주문건 보면 정말 신기하기도 하고
# 이제 정말 많은 분들이 마와를 알게 된 것 같아서 최초 진행자(?)로써 참 뿌듯하고 그렇습니다😆크크
#
# 🧶 저는 간절기, 겨울에는 니트만 입을 정도로 니트를 정말 좋아하는데요!
# 니트를 옷걸이에 걸어뒀을 때 발생하는 어깨뿔, 넥라인 늘어남이 고민이었어서
# 서치해 보다가 알게되어 내돈내산으로 사용하던 제품이 바로 마와였어요🫶🏻
#
# 처음 진행 할때만 해도 제가 옷걸이만 70만원 이상 구매 했다고 했을 때 다들
# 에?70 너무 오바 아니야?하는 분위기였는데 이제 저보다 더 한 분들 정말 많으시다구요ㅋㅋ
# 한 번에 180만원 가량 구매하신 고객님들도 여럿 계세요🙊ㅋㅋ
#
# 저도 21년 3월에나 70만원이었지 아직도 야금야금 계속 구매하고 있어서
# 저희집에 있는 마와 옷걸이 비용 다 따지면 200만원은 족히 넘을 거예유😆
#
# “옷걸이에 200만원을 태운다고?미친거 아냐,,?”
# 하실 수 있지만 마와는 확실히 그 이상의 가치를 하는 아이템이에요.
#
# 🧔🏻‍♂️ 특히 남편분들이 처음에는 옷걸이 가격 듣고 놀라서 뭘 이렇게 비싼 걸 사냐고 하더니
# 막상 사용해 보면 자기 옷은 꼭 마와에 걸고,,이거 언제 더 살 수 있냐고, 더 사라고 얘기한다는 후기 정말 많습니다,,😇
#
# ⛱️ 우리집 옷방, 장농, 시스템장의 크기는 한정적인데 우리는 매 계절마다 새로운 옷을 사잖아요.
# 그러다 보니 옷을 걸 공간이 점점 없어지는 건 당연하겠죠🥲
#
# 마와로 공간을 구매 하실 수 있어요🪄
# 마와가 없던 공간을 만들어 드리는 건 물론이고
# 어깨뿔 고민, 깔끔한 옷방을 완성시켜 드릴게요🤍
#
# 📦 1401HOME에서는 단 한세트만 구매해도 무료배송 적용되니 제일 최저가로 진행하는 1401HOME 기획전 통해서 마와 입문해 보세요🤍
#
# 🪄 어떤 종류를 사야할지 모르겠다면, 가지고 있는 의류 종류를 댓글로 남겨주시면 안내해 드릴게요🫶🏻
# 댓글 수: 250
# 좋아요 수: 비공개
# 미디어 타입: REELS
# 타임스탬프: 2023-06-26T23:10:00+0000
# 사용자명: b.saem
# 사용자 코드: 17841400161289712
# -------------------------------------------------------------------------
# 게시물 ID: 17987239595124058
# 캡션: 쓸 말은 없구요 사진은 올리고 싶습니다,,,🤭🤍
# 저는 오늘 차돌박이랑 고사리 넣고 파스타를 만들어 먹을 거예욤 먹어보고 맛있으면 레시피 공유할게요😆
# 즐거운 저녁 시간 되세요🫶🏻
# (결국 말 많이 함)
# 댓글 수: 16
# 좋아요 수: 비공개
# 미디어 타입: FEED
# 타임스탬프: 2023-06-26T08:52:57+0000
# 사용자명: b.saem
# 사용자 코드: 17841400161289712
# -------------------------------------------------------------------------
# 게시물 ID: 17999204533910668
# 캡션: 🎪 이벤트 있어요✨
# 1401HOME 기획전 기준 누적 판매갯수 57만개 / 누적 후기 3300개의 마와 옷걸이☁️
# 정말 많은 분들이 이미 빠진 마와 옷걸이이지만 아직도,,안써보신 분들도 계시겠죠?🥹
#
# 요즘 기온이 높아져서 안그래도 불쾌지수가 높은데,
# 정리안된 옷 방 들어갈 때마다 또는 정리안된 헹거를 볼 때마다 스트레스 받으셨다면😡
# 마와 꼭 한번 사용해보세요,,제발🙏🏻
# 우리집 옷방도 깔끔해 질 수 있어요 마와가 구원해 드립니다😆
#
# 제 옷방 인생은(?) 마와를 쓰기 전,후로 나뉜다고 말할 수 있을 정도라서
# 많은 분들이 꼭 경험해 보셨으면 좋겠어요🦢
#
# 특히 여름 옷 정리에 더 빛을 발하는 [이코노믹 라이트]로 여기저기 널려 있는 티셔츠 싹 정리해 보세요.
# 깔끔하게 정리 된 옷 방에 들어가는게 행복해지는 순간이 분명 올 거예요🫶🏻
#
# 🏷️ 돈 아깝게 옷걸이에 돈을 왜 써? 하시는 분들 이번 기획전 때 구매하시면
# 1세트만 구매하셔도 무료배송 적용되니 딱 한세트만 먼저 사용해 보세요!
# 마와가 그 편견을 깨트려 드릴게요🪄
# 그리고 마와는 1401HOME 기획전에서 구매하시는게 저렴합니다🙊
#
# 🧺 마와 옷걸이, 이런 분들께 추천해요!
# ▸ 드레스룸, 장농, 헹거에 더 이상 옷 걸 자리가 없다면
# ▸ 아무리 버리고, 정리를 해도 옷 방이 깔끔해지지 않는다면
# ▸ 니트, 티셔츠의 어깨뿔, 넥라인 늘어짐 때문에 스트레스 받으셨다면
# ▸ 걸어두면 스르르 떨어져 버리는 옷 때문에 스트레스 받으셨다면
# ▸ 의류관리기에서도 사용 가능한 옷걸이가 필요 하셨다면
#
# 👉🏻이제 더 이상 미루지 말고 당장 마와를 사용하셔야 합니다✊🏻
#
# ⏰ 마와는 6월 27일(화) 오전 8시에 오픈됩니다✨
#
# 👜 옷걸이 구매 하시면서 활용도 정말 높은 가방걸이도 꼭 같이 구매해 주세요🫶🏻
#
# 🧶 다음 기획전은 3개월 뒤 진행 예정이니 앞으로 새로 살 옷들까지 대비해서 2-3세트씩 좀 더 여유있게 구매하시는 것 추천해 드려요!
#
# 📦 이노코믹, 실루엣, 이코노믹 라이트, 실루엣 라이트 화이트 컬러는 품절이 빠른 품목이니 기다리셨던 분들은 서둘러 주문해 주세요!
#
# 🎪 해당 피드에 “알람” 댓글 남겨주시면 15분을 추첨하여
# 여름철 옷정리에 꼭 필요한 이코노믹 라이트 10개를 선물로 보내드릴게요🍉
# 댓글 수: 348
# 좋아요 수: 비공개
# 미디어 타입: FEED
# 타임스탬프: 2023-06-25T12:37:59+0000
# 사용자명: b.saem
# 사용자 코드: 17841400161289712
# -------------------------------------------------------------------------
# 게시물 ID: 18002285620875066
# 캡션: 제주도 이모저모🍉🧃⛱️
#
# 🏷 진행했던 이벤트 당첨자분들 발표할게요!
# 많은 분들이 정성스럽게 참여해주셔서 뽑기가 늠 힘들더라구요🥺
# 참여해주신 모든 분들께 선물을 드리고 싶은 제 맘 꼭 알아주세요,,🫶🏻
#
# 다음에도 많은 분들이 당첨 되실 수 있게 풍부한 이벤트들 많이 가져올게요🎁
#
# 당첨되신 분들은 제 프로필 링크에 연결되어 있는 블로그에
# 비밀댓글로 정보 남겨주세요! 축하드립니다🤍🤍🤍
#
# [뷰티콜라겐] 체험단 이벤트 (뷰티 콜라겐 30ea*2box, 5명)
# luv_0823
# bbin_1994
# __uzza._
# bmj_1112
# kk__yh000
#
# 💌 콜라겐은 1박스를 먼저 보내드리고, 추가 수량이 입고되는 7월 초에 1박스를 더 보내드려서
# 총 2박스를 보내드릴 예정입니다! 드셔보시고 실제로 느낀 후기를 꼭 알려주세요✨
#
# [베이지크] 댓글 후기 이벤트 (핸드&네일크림+스퀴저 세트, 10명)
# jenny_901102
# purlotdus
# seonshine_
# mimiyo.kk
# _jinshim
# eunoo_land
# bbichime
# gogoyukari
# arome_de_mk
# igotmmm
#
# [베이지크] 스토리 구매인증 이벤트 (선스크린 1개, 10명)
# zl.rlo__bb
# sj___jin
# zzoins
# 55555.21.23
# yooni71210
# 830177_
# ahra__cho
# jju_______u
# home_byjh
# hyem357
#
# [구디] 댓글 기대평 이벤트 - 5명 (이뮨스틱 1Box, 5명)
# popsongofdream
# _echri_12
# mrs.won2
# candy_mjchoi
# cho.e_
#
# [구디] 스토리 구매인증 이벤트 - (이뮨 스틱 1Box, 20명)
# y._.yms
# sarang_caritas
# gio__mom
# soye_yuan
# bnyy_y
# eun_02x2
# zsun.zzang
# geeee1_26
# y_y_hyejeong
# kkkkp825
# greenlmj
# _slmung
# garimoooo
# i_choara
# torine_zip
# a._.reumm
# autumnlight_990
# jjidduyya
# seo_u__
# happy_haenny
#
# 그리고 깜빡하고 발표 안했던 이벤트가 있더라구요 🥺
# 늦었지만 네스프레소 구매 완료 이벤트도 발표합니다🫶🏻
#
# [네스프레소] 스토리 구매인증 이벤트 (10만원권 상품권, 3명)
# moonjung__
# offofshop
# rannmi
#
# [네스프레소] 피드 구매완료 이벤트 (5만원권 상품권, 3명)
# _jin_e___
# starkim0529
# artloveshim
# 댓글 수: 51
# 좋아요 수: 1095
# 미디어 타입: FEED
# 타임스탬프: 2023-06-23T12:58:46+0000
# 사용자명: b.saem
# 사용자 코드: 17841400161289712
# -------------------------------------------------------------------------
# 게시물 ID: 18013351453647262
# 캡션: 롱롱이랑 제주도로 가족 여행 왔오요😆
# 스토리 보시고 문의 디엠이 많이 와서 한번에 정리해서 올립니당🩵🩵🩵
#
# ① 성인 6명에 강아지까지 함께하는 여행이라 예쁜 숙소 찾기 힘들었는데
# 요기 괜찮죠🤍
# 전체적으로 깔끔하고 침대도 3개라서 너무 좋았는데,
# 주변에 밭이 있어서,,,창문 열어두면 거름 냄새가 쩜 났습니다🥹
#
# 구좌읍 하도리에 있는 숙소고 에어비앤비로 예약했어요!
# 주소는 아래 기재해 둘테니 컴퓨터로 들어가서 링크 복사해서 보시면 될 것 같아요😊
# https://abnb.me/jdOwPSoMPAb
#
# ② 상의: #미디어82 요가 베이비 티
# 하의: #원로그 핀스트라이프 팬츠
#
# ③ 하트 보조 배터리는 모지 파워 제품⚡️
#
# 🏷️ 그리고 미역밭(?)을 신나게 뛰어노는 아가 롱롱이🐶
# 바다에서 뛰어노는 걸 이렇게 좋아할 줄이야🥹
# 올 여름은 바다 종종 가야겠어요 흐흐
#
# 🏷️ 제주도에는 딱새우회를 꼭,,,꼭,,,드셔주세요🦐
#
# 🏷️ 초롱이 트레이드 마크인 “친구야 냄새 편하게 맡아” 자세ㅋㅋㅋㅋ
#
# 🏷️ 많이 기다리시는,,숙취해소제가 되버린(ㅋㅋ)콤비타는 7월 11일에 돌아옵니당😆
# 댓글 수: 13
# 좋아요 수: 비공개
# 미디어 타입: FEED
# 타임스탬프: 2023-06-22T09:09:06+0000
# 사용자명: b.saem
# 사용자 코드: 17841400161289712
# -------------------------------------------------------------------------
# 게시물 ID: 17989890082908875
# 캡션: 1401HOME 자체 제작 니트 블랭킷✨
# 컬러 너어무 상콤하지 않나요🍉
#
# 🛌 가정에서 💻 사무실에서 🍼 아가들 유아차용 블랭킷으로는 물론이고
# 두꺼운 원사로 한올 한올 편직되어 도톰하게 짜여진 니트 블랭킷이라서
# ⛱️ 공원, 바다에서 툭 깔아놓고 피크닉매트 대용으로도 편하게 사용하실 수 있어요🫶🏻
#
# 저는 이번에 하와이 갔을 때 피크닉 매트로 쓰다가 물놀이 하고 나와서 추우면
# 블랭킷으로도 사용하고 그랬어요😋
#
# 100*150의 넉넉한 사이즈라서 몸에 충분히 두를 수 있고
# 피크닉 매트로 사용하는 경우에는 성인 2명이 앉아서 간단하게 사용하실 수 있는 사이즈에요🤍
#
# 어디에서도 만나볼 수 없는 1401HOME만의 무드로 만들어진 바넷 니트 블랭킷!
# 지금 바로 홈페이지에서 만나보세요☁️
#
# 🚚 낮 12시 이전 구매건에 한하여 당일 출고 됩니다.
# 댓글 수: 14
# 좋아요 수: 비공개
# 미디어 타입: FEED
# 타임스탬프: 2023-06-20T11:44:48+0000
# 사용자명: b.saem
# 사용자 코드: 17841400161289712
# -------------------------------------------------------------------------
# 게시물 ID: 18022202461576890
# 캡션: 🎪댓글 이벤트 있어요😆
#
# 여름에 과일 많이 드시죠🍓🍋🍉🍒
# 바로우만 있으면 과일도 간단하게 세척해서 드실 수 있어요!🫶🏻
#
# 바로우는 먹을 수 있는 성분으로만 만들어진 1종 고체 세제로
# 뽀득뽀득한 설거지는 물론이고
# 과일, 야채, 아기 젖병, 장난감까지 안전하게 세척이 가능합니다.
#
# 🍓 바로우로 거품을 낸 물에 과일, 야채를 15초 정도 담가두었다가
# 깨끗한 물에 헹구어 내면 잔류농약 걱정없이 안전하게 드실 수 있어요!
#
# 🍽️ 주방에 세제, 베이킹소다, 핸드워시 따로 두지 마세요!
# 바로우 하나면 깔끔한 주방 완성입니다💫
#
# ⚠️ 과일, 야채, 젖병 세척이 가능한 1종 세제는 화학성분이 포함되어 있어도 1종으로 분류되기 때문에 과일, 야채, 젖병 세척은 먹을 수 있는 성분으로만 만들어진 바로우로 세척하시는 걸 권장드립니다.
#
# 🎪 깜짝 이벤트 한번 가볼까요!
# 아직도 고체세제에 대해 의심하는 분들,,😎
# 제가 입문시켜 드리겠습니다 흐흐
#
# 바로우로 닦을 수 있는 것들을 자유롭게 이모티콘으로 남겨주세요!
# 3분을 추첨해서 바로우 디쉬바 2ea+트레이를 선물로 보내드릴게요🎁
#
# ⏰ 바로우 특별 기획전은 내일(일요일) 자정 마갑 됩니다✨
# 댓글 수: 122
# 좋아요 수: 비공개
# 미디어 타입: REELS
# 타임스탬프: 2023-06-17T01:10:00+0000
# 사용자명: b.saem
# 사용자 코드: 17841400161289712
# -------------------------------------------------------------------------
# 게시물 ID: 17859470198934169
# 캡션: ⚠️ 4번째 잔류세제 영상 꼭 봐주세요!
# 여태까지 이렇게 먹은 액체세제가 얼마나 될지 가늠도 안돼요🥹
# 이제부터라도 액체세제 그만 먹어요 우리🥲
#
# 안그래도 어지러운 주방에
# 굳이 세제+베이킹소다+핸드워시까지 나와있을 이유가 없죠🪄
#
# 바로우는 식약처 인증 1종 고체 세제로
# 🍽️ 설거지 🍒과일+야채 세척 🍼젖병 세척은 물론 🙌🏻 핸드워시의 기능까지 갖춰서
# 주방에 지저분하게 이것저것 둘 필요 없이 바로우 하나로 깔끔한 주방을 연출할 수 있어요🤍
#
# 거기다 바로우 감성 그대로 담긴 이 트레이는 또 얼마나 예쁘게요,,🕊️
# 다 쓰면 매번 나오는 플라스틱 세제 통 쓰레기도 줄일 수 있고,
# 미세 플라스틱 걱정까지 덜 수 있어서 하 이건 뭐 장점 나열하기도 손가락 아플 정도구요🙊
#
# 🥦 야채, 과일에 남은 잔류 농약은 흐르는 물에만 헹구어 내도 닦인다고 하지만
# 아무래도 좀 찝찝해서 저는 꼭 바로우로 세척해서 먹고 있어요!
#
# 특히 대파 같은 경우는 보통 물에 대충 헹궈서 사용하는 경우가 많은데,
# 5번째 비교 사진 보시면 비포 애프터 보면 차이가 확실히 보이실 거예요!
# 바로우는 고체 타입이다 보니 손에 거품 내서 뿌리 딱 잡고 손으로 슥슥 문질러서 닦아주면 되니깐 너무 편하더라구요🙊
#
# 🍒 바로우로 거품을 낸 물에 과일, 야채를 15초 정도 담가두었다가
# 깨끗한 물에 헹구어서 드시면 잔류농약 걱정없이 안전하게 드실 수 있어요!
#
# ⚠️ 과일, 야채, 젖병 세척이 가능한 1종 세제는 화학성분이 포함되어 있어도 1종으로 분류되기 때문에 개인적으로 과일, 야채, 젖병 세척은 먹을 수 있는 성분으로만 만들어진 바로우로 세척하시는 걸 권장드립니다.
#
# 🔖 바로우 진행하면서 고객님들 얘기 들어보니깐
# 다른 고체세제 사용해 보시고 고체세제에 대한 편견이 생긴 분들이 종종 계시더라구요🥹
#
# -고체세제는 기름기가 잘 안닦인다.
# -고체세제는 물 자국이 많이 남는다.
# -고체세제는 금방 물러져서 끝까지 쓰기 어렵다.
#
# 이런 이유로 고체세제 사용하지 않으셨던 분들!
# 바로우가 고체세제에 대한 편견을 깨트려드릴게요⚡️
# 저 믿고 바로우 한번 써보세요🫶🏻
#
# 💧고체세제는 물 자국이 많이 남는다!?
# 고체세제 사용 후 남는 물 자국은 제품 자체의 문제가 아닌
# 물에 있는 미네랄이 비누의 지방산과 반응하여 생기는 현상이에요.
#
# 이는 같은 세제를 사용하더라도 수질(미네랄 수치)에 따라 정도가 다르기 때문에
# 같은 제품을 사용하더라도 이사를 가면 현상이 덜해지거나
# 수전에 필터를 달면 물 자국이 덜해지는 경우도 있더라구요!
#
# 액상세제는 이런 물자국을 없애기 위해
# 화학성분인 금속 이온 봉쇄제(EDTA=피부자극 및 수질 오염)를 넣고 있어요.
#
# 바로우 디쉬바는 EDTA 대신 자연 유래 성분인 베이킹소다, 소금, 식초 성분으로 물자국을 최소화 하여서 다른 고체바에 비해 물자국이 적은 편이랍니다.
# (실제로 저희 집에서 사용했을 때에는 액상세제 보다도 물 자국이 적게 남았어요.)
#
# 하지만 가정마다 다른 수질의 차이로 물 자국이 남는다면
# 설거지 하실 때 되도록 따듯한 물로 헹궈주시거나 설거지 직후 마른 행주로 물기를 닦아주시는 걸 권장합니다😊
#
# 🎪바로우 스토리 이벤트!
# 제품 받아보신 뒤 또는 구매내역을 캡쳐한 후
# 제 아이디를 태그해서 스토리에 공유해 주세요!
#
# 5분을 추첨해서 바로우 디쉬바 3개를 선물로 보내드려요🕊️
# 댓글 수: 7
# 좋아요 수: 비공개
# 미디어 타입: FEED
# 타임스탬프: 2023-06-16T04:34:15+0000
# 사용자명: b.saem
# 사용자 코드: 17841400161289712
# -------------------------------------------------------------------------
# 게시물 ID: 17873638253861307
# 캡션: 액상세제 희석해서 사용해야 한다는 건 알지만
# 희석해서 사용하면 뭔가 다 닦이지 않은 것 같은 찝찝한 느낌에
# 그냥 원액 그대로 사용하시는 분들 아직도 많으시죠🥺
#
# 세제를 잘못된 방법으로 사용하실 경우 그릇에 묻은 세제가 제대로 헹구어 지지 않아서
# 식기에 남은 잔류세제는 음식을 통해 우리 몸 속에 차곡차곡 쌓이게 된답니다.
#
# 이렇게 쌓인 세제는 무려 1년에 소주 3잔, 10년이면 소주 2병의 양이라고 해요😳
#
# 바로우 1종 고체세제는 15가지의 전성분 모두 먹을 수 있는 성분으로만 만들어져
# 설거지 / 야채, 과일 세척 / 아기 젖병, 장난감 세척 / 손 세척까지 가능한 멀티 디쉬 바 입니다🍽️
#
# 🧼 바로우는 정제수가 들어가지 않아서 액상세제보다도 쫀쫀하고 농밀한 거품이 각종 기름때를 뽀득뽀득 닦아주며, 베이킹 소다와 소금, 식초 성분이 함유되어 있어 물자국을 최소화 했어요!
#
# 🙌🏻 난 고무장갑 절대 못껴,,!!
# 평소에 맨손 설거지 하시는 분들은 꼭 바로우 사용해 주세요🙊
#
# 바로우 디쉬바는 무려 1,000시간 저온 숙성 기법으로 제작한 비누로
# 저온으로 숙성할때만 만들어지는 천연 글리세린이 풍부하게 함유되어 있어서
# 더욱 촉촉하고 매끈거리는 사용감으로 만들어 준답니다.
# 맨 손 설거지는 물론이고 마무리 손 세정까지 디쉬바 하나로 해결해 보세요!
#
# 🫧 이전에 고체 세제 사용 하셨다가 실망하신 분들!
# 바로우 한번 써보시면 고체세제에서 느꼈던 불편한 기억들 싹 사라지실 거예요✨
#
# 🏷️ 구매는 인스타 프로필 링크 통해서 가능합니다🤍
# 댓글 수: 6
# 좋아요 수: 비공개
# 미디어 타입: REELS
# 타임스탬프: 2023-06-14T08:05:13+0000
# 사용자명: b.saem
# 사용자 코드: 17841400161289712
# -------------------------------------------------------------------------
# 게시물 ID: 18220138213232887
# 캡션: 1종 고체 주방세제 바로우 오픈 했습니다🍽️✨
#
# 지난 1차 기획전 때 정말 많은 사랑 받은 제품!
# 사실 7월 진행 예정이었는데, 똑 떨어졌다며,,빨리 오픈해 달라는 강력한 요청이 많아서 급하게 일정 잡아서 데리고 왔어요🤭
#
# 1차 기획전 때 구매해서 사용해 보신 분들!
# 어떠셨나욤🙋🏻‍♀️
# 직접 써보시니 바로우 제가 그렇게 극찬한 이유 아시겠죠🫧
#
# 저는 집안살림 중에서 설거지를 가장 싫어하는 사람이라
# 설거지를 깔끔하게 빨리 끝내고 싶은 마음에 정말 많은 세제를 사용해 봤어요.
#
# 유명 해외 브랜드 제품부터 고체 타입의 세제들도 많이 써봤지만
# 어떤 제품 하나 만족스러운게 없더라구요.
# 성분이 괜찮으면 세정력이 아쉽거나
# 세정력이 괜찮으면 거품이 부족하다거나,,
# 제가 원하는 모든게 충족되는 제품을 찾지 못했었어요🥹
#
# 그렇게 몇 년동안 세제 떠돌이 생활을 하다가 정착하게 된 제품이 바로 "바로우 디쉬바" 입니다🙊
# 세정력+거품+촉촉한 손 보호까지 다 갖춘 디쉬바가 친환경 1종 주방세제라니🥺
# 안써 본 사람 없게 해주세요 제발,,🙇🏻‍♀️
#
# ⚠️ 우리는 왜 1종 고체 세제를 사용해야 할까요?
#
# 액상세제의 경우 5L 물에 세제를 한 번만 펌핑해서 희석해서 사용해야 하는데
# 보통 원액 그대로 사용하다 보니 아무리 헹구어 내도 그릇에는 잔류 세제가 남게되고
# 그릇에 남은 잔류세제는 음식에 그대로 묻어서 우리 몸 속에 조금씩 축적되고 있어요.
#
# 세제를 희석해서 사용한다고 해도 액상 세제를 담은 플라스틱 용기는 환경 오염이나 미세 플라스틱 등 다양한 문제를 일으키기도 하구요.
#
# 특히 아이가 있는 가정이라면 무.조.건 고체 세제를 사용해 주세요👶🏻
# 우리집은 아이가 없으니 괜찮아! 라고 생각 하시는 분들🙅🏻‍♀️
# 액상세제를 희석하지 않고 그대로 사용시 1년에 소주잔 기준 3잔 정도의 잔여세제가 몸에 축적되고 있어요!
#
# 특히 액체세제는 방부제, 화학 계면활성제가 포함되어 있어도
# 1종으로 분류가 가능해서 같은 1종 세제여도 고체 세제를 사용하시는게 안전하답니다😊
#
# 🏷️ 우리 가족의 건강을 위해서 1종 고체 세제를 사용을 권장해 드려요.
#
# _
#
# 1종 고체세제를 사용해야 하는 이유, 이제 납득이 되셨죠?
# 1종 고체세제 [바로우 디쉬바]는 설거지는 물론이고 우리가 먹는 과일 및 채소 세척, 아기의 젖병, 장난감 세척이 가능하고 설거지 후 마무리 손세척까지 가능해서 멀티 디쉬바로 사용하실 수 있어요.
#
# 🧼 뽀득뽀득 소리 날 때까지 설거지 하시는 분들은 다른 세제로 힘 들이지 마시고
# 바로우 한번 사용해 보세요!
# 미끌거리는 기름때도 쉽게 닦아내진답니다🫧
#
# 🙌🏻 바로우 디쉬바는 주방세제+베이킹 소다+핸드워시가 합쳐진 멀티 디쉬바로
# 세제, 베이킹소다, 핸드워시를 대체해 주어서 깔끔한 주방을 유지할 수 있어요🧃
#
# 안심하고 세척 할 수 있는 천연 유례의 원료로 만들어진 [바로우 디쉬바]
# 1401HOME에서 최저가로 만날 수 있는 특별 기획전은 이번주 금요일 마감 입니다🤍
#
# 🎪바로우 스토리 이벤트!
# 제품 받아보신 뒤 또는 구매내역을 캡쳐한 후 제 아이디를 태그해서 스토리에 공유해 주세요!
#
# 5분을 추첨해서 바로우 디쉬바 3개를 선물로 보내드릴게요🕊️
#
# 🛍️ 선물용 종이 가방이 추가되었어요!
# 바로우의 감성이 그대로 담긴 디자인으로 옵션 5,6번 구매시 함께 발송해 드립니다✨
#
# 🚚 오후 2시 이전 주문건에 한하여 당일 출고 됩니다.
#
# / BARAW DISHBAR /
#
# ▸ 식약처 인증을 받은 1종 자연 유래 고체세제
# ▸ 입에 닿아도 안전한 15가지의 식물유래 전성분
# ▸ 잔류 세제 걱정이 없는 고체타입
# ▸ 물은 0.1%도 들어가지 않은 농밀한 거품으로 강한 세정력
# ▸ 소금 및 식초 성분 함유로 물자국 최소화
# ▸ 1,000시간 저온 기법으로 제작하여 촉촉한 사용감
# ▸ 천연 글리세린, 시어버터, 병풀 추출물 함유
# ▸ 주방세제+베이킹 소다+핸드워시를 합친 올인원 멀티 제품
# ▸ 제로 웨이스트! 플라스틱이 없는 친환경 세제
# 댓글 수: 10
# 좋아요 수: 비공개
# 미디어 타입: FEED
# 타임스탬프: 2023-06-14T02:10:06+0000
# 사용자명: b.saem
# 사용자 코드: 17841400161289712
# -------------------------------------------------------------------------
# 게시물 ID: 17852970023961204
# 캡션: 진짜 오랜만에 카라반 끌고 캠핑 다녀온 어제🚐💨
#
# 친구부부랑 가서 노느라 바빠서 갬성은 못챙겼지만ㅋㅋ
# 도착해서 부터 자기 직전까지 맛있는 거 잔뜩 먹고 깔깔대고 왔어유 흐흐
#
# 그나저나 도착해서 세팅하는데 갑자기 비 쏟아지길래 와 오랜만에 우중캠이다!!하고 좋아했는데
# 막상 또 비 그치더니 조금 있다가 또 소나기 오고 계속 반복😂
# 우리나라 언제부터 이렇게 동남아 날씨 처럼 된거죠🥹
# 아무튼 결국엔 맑은 날씨+뽕따로 마무리🤍🤍🤍
#
# 🏕️요기는 포천에 폴라데이 캠핑장이에요!
# 일타스캔들에서 정경호가 낚시하던 그 곳,,🙊
# 캠핑장 안에 낚시터가 있어서 낚시하시는 분들 가시면 너무 좋을 것 같구요🎣
#
# 수영장도 있어서 여름에 아이들 놀기에도 좋아서 추천합니둥🫶🏻
# 댓글 수: 7
# 좋아요 수: 비공개
# 미디어 타입: FEED
# 타임스탬프: 2023-06-13T12:05:26+0000
# 사용자명: b.saem
# 사용자 코드: 17841400161289712
# -------------------------------------------------------------------------
# 게시물 ID: 17991391037006199
# 캡션: 스토리에 올릴 때마다 레시피 문의가 넘쳐나는 토마토 스튜🍅
# 사실 재료만 있으면 누구나 할 수 있는,,레시피라고 할 것도 없는 간단한 요리인데
# 바게트 빵이랑 같이 먹으면 얼마나 맛있게요😋🤍
# 저는 캠핑가서 오오디커피 (oodi_coffee)사장님이 해주셔서 먹어보고 꽂혀서 그 이후로 주기적으로 먹고 있습니당 크크
#
# 재료 준비해서 주말 아침에 꼭 드셔보세요☕️
#
# 재료:
# 토마토 파스타 소스 1병 , 소고기 양지 반근, 다진 마늘, 감자, 당근, 양파, 바게트 빵
#
# 🏷️ 올리브유를 두른 냄비에 소고기 양지+다진마늘 한스푼 넣고
# 고기가 익을 때까지 볶은 후
# 토마토 파스타 소스 1병, 정수 200ml, 감자, 당근, 양파, 치킨스톡 반개를 넣고 30분 이상 중약불에서 푹 끓여주면 완성!
# 진짜 간단하죠?🙊
#
# - 눌러붙을 수 있으니 중간중간 열어서 저어주셔야 해요🥄
# - 농도는 중간중간 보면서 물로 조절해 주세요.
# - 싱거우면 치킨스톡 반개 정도 넣어주시면 좋아요!
# - 스타우브, 르쿠르제 같은 주물 냄비에 뚜껑 덮고 끓여야 고기가 부드러워지고,
# 야채가 많을 수록 맛있어요✨
# - 기본 재료 외에 양송이버섯, 브로콜리 등 좋아하는 재료 마음껏 넣어주세요🫶🏻
# - 바게트빵은 올리브유에 앞 뒤로 살짝 구워서 먹으면 더 맛있어요😚
# 댓글 수: 8
# 좋아요 수: 비공개
# 미디어 타입: FEED
# 타임스탬프: 2023-06-13T07:56:06+0000
# 사용자명: b.saem
# 사용자 코드: 17841400161289712
# -------------------------------------------------------------------------
# 게시물 ID: 17973900464511784
# 캡션: 🎪 체험단 이벤트 있어요!
#
# 제가 또,,,대박 제품을 가져왔습니다 여러분🥹
# 마시는 뷰티콜라겐 정말 많이 보셨죠?
# 근데 그 흔하디 흔한 뷰티콜라겐을 제가 왜 소개해 드릴까요?🙊
# 이 뷰티콜라겐을 여태까지 보셨던 뷰티콜라겐이랑은 완전히 달라요
#
# 소개해 드릴 제품은 세계적인 독일 건강기능식품 전문 기업인 “크로이터하우스”의 뷰티콜라겐인데요✨
#
# ”콜라겐”이 함유되어있는 건 당연하고
# 피부 수분을 꽉 잡아주는 ”히알루론산”
# 피부들 부드럽고 매끄럽게 유지하는데 도움을 주는 “비타민 A”
# 콜라겐 흡수를 돕는 ”비타민 C”
# 피부에 수분을 공급하고 건강한 피부 조직을 유지해 주는 ”비타민 E”
# 거기에 콜라겐 생산을 촉진하여 피부 탄력을 향산 시켜주는 ”아연”
# 피부 탄력 및 색소 침착을 완화하는데 도움을 주는 ”구리”
# 피부, 머리카락 건강에 중요한 영양소인 ”비오틴”
# 피부 건강 개선을 위한 ”카로틴”까지
# 피부, 머리카락, 손톱 건강을 위한 영양소가 한병에 꽉 차 있는 그런 뷰티 드링크에요🧃
#
# 일반적으로 마시는 콜라겐! 하면 보통 콜라겐+비오틴 또는
# 콜라겐+비타민C 정도만 함유되어 있는 제품들이 대부분이랍니다.
#
# 👩🏻 제 팔로워 분들 중에 30-40대 여성분들이 가장 많은데요!
# 연구에 따르면 콜라겐 생성은 20대 중반부터 천천히 감소하기 시작해서
# 30대 중반부터 40대에 이르면 콜라겐 생성이 눈에띄게 감소한다고 해요.
# 이 때부터 주름과 기미, 검버섯 등이 생기기 시작하고
# 50대 이후에는 콜라겐 생성이 급격히 감소한다고 해요.
# 참고로 콜라겐은 피부 뿐만 아니라 관절, 인대, 뼈, 근육, 손톱과 머리카락에도 영향을 미친답니다🥺
#
# 🪞슬프지만,,
# 이제 우리 몸에서 생산되는 콜라겐에 의지할 수 없는 나이에요💧
#
# 실제로 저는 이 뷰티드링크를 먹었을 때
# ‘아 내 몸에서 콜라겐이 필요 했구나,,’ 라는게 느껴질 정도로
# 몸에서 콜라겐을 쏙쏙 흡수하는게 온 몸으로 느껴지더라구요!
#
# 🩰 저는 뷰티드링크를 섭취한지 1주일 째부터 피부로 효과를 느꼈고
# 효과가 느껴지다 보니 하루도 빼먹지 않고 3개월 째 매일 먹고 있어요.
# 사실 효과가 안느껴지면 이런 제품들도 먹다가 안먹게 되잖아요.
# 하지만 크로이터하우스의 뷰티드링크는 다릅니다🙊
#
# 뷰티 드링크 마시고 나서 확실히 피부 속광이 달라졌고
# 피부가 탱탱해지는게 눈에 보이더라구요😳
# 개인적으로 좋은 팩, 좋은 화장품 쓰는 것보다 확실히 효과가 더 크게 느껴졌어요!
#
# 심지어 콜라겐 섭취하고 나서 만난 친구들이 경락 받았냐고
# 얼굴 작아졌다고 물어보구요🥺
#
# 피부결이 매끄러워지니깐 친구들 만나거나 미팅 나가면 피부 칭찬을 꼭 듣는데,
# 그냥 평범한 피부였던 제가 정말 36년만에 처음으로 피부 칭찬 듣는게 너무너무 신기했어요🪩
#
# 심지어 얼굴 피부 뿐만 아니라 몸 피부까지 촉촉해진게 느껴지는 요즘입니다🍉
#
# (제 스토리 보시는 분들은 아시겠지만
# 제가 두 달 전쯤에 써마지를 했는데, 위에 적은 내용은 써마지 하기 전에 들은 칭찬들이고
# 써마지는 뷰티드링크의 효과를 보고 나서 시술 받은 거예요😋
# 평소 울쎄라, 써마지, 스킨보톡스 같은 시술 받는 분들이 드셔주시면 더 효과볼 수 있는 뷰티 드링크 입니다🧃✨)
#
# 🏷 그리고 제가 항상 강조하는 꾸준한 복용!
# 영양제는 꾸준히 복용해서 체내 혈중 농도를 유지하는게 가장 중요한데요-
# 이렇게 꾸준히 복용해야 하는 영양제의 가격대가 너무 높으면
# 지출이 부담스러워서 결국 복용을 중단하게 되는데
# 그러면 정말 말짱 도루묵이거든요🥹
#
# 👉🏻 이번에 소개해 드리는 크로이터하우스 상트베른하르트 뷰티 드링크는
# 30개입 한달치를 5만원대로 만나보실 수 있어서 부담없이 꾸준히 드실 수 있어요!🦢
#
# 🍅 맛의 경우 콜라겐 특유의 비린맛이 없고
# 개인적으로는 꾸덕한 토마토 쥬스 같은 맛으로 느껴지더라구요!
#
# 🎪 한국에서는 1401HOME에서 첫 런칭하게 된 크로이터하우스의 뷰티드링크!
# 꾸준히 드시고 후기 보내주실 체험단 5분을 모집할게요🫶🏻
# 댓글로 아무 말이나 편하게 남겨주세욤!
#
# 체험단으로 선정되신 분들께는 다음주 중 1박스 (30ea)를 먼저 보내드리고,
# 추가 수량이 입고되는 6월 말에 1박스를 더 보내드려서 총 2박스를 보내드릴 예정입니다😚
# 드셔보시고 실제로 느낀 후기를 보내주실 수 있는 분들의 많은 참여 부탁드려요🫶🏻
#
# 🏷 크로이터하우스의 뷰티드링크는 7월 18일에 한국 최초로 1401HOME에서 런칭 될 예정입니다!
# 런칭 때는 피부 비포 애프터 사진도 보여드릴게요🫶🏻
# 댓글 수: 143
# 좋아요 수: 비공개
# 미디어 타입: FEED
# 타임스탬프: 2023-06-11T12:41:05+0000
# 사용자명: b.saem
# 사용자 코드: 17841400161289712
# -------------------------------------------------------------------------
# 게시물 ID: 17980862882257708
# 캡션: 구디 면역력 스틱은 오늘 자정 마감 됩니다🍋
# 다음 기획전은 3개월 뒤라서 기본 6박스(4개월치) 구매를 권장해 드려요!
# 저는 남편이랑 둘이 먹을 거라서 12박스 쟁였어요🥳
#
# 이번에 제 하와이 스토리 보고 구매하셨다는 분들도 많이 계시더라구요ㅋㅋㅋ
# 얘가 도대체 하와이에서 어땠길래 그래,,하신다면 프로필에 있는 스토리 하이라이트를 봐주세요🙊
# 정말 누가 저희 지켜보고 있었으면 질려했을 정도로 하루종일 나가 놀았는데,
# 예전에는 정말 상상할 수 없던 체력이거든요,,
# 진짜 제 하와이 체력은 200% 이뮨 덕입니다💃
#
# 🍉 구매인증 스토리도 진행 중이에요!
# 제 아이디를 태그해서 구매인증 스토리를 올려주신 20분께 구디 이뮨 스틱 1박스씩 선물로 드려요✨
# (깜짝 이벤트라 오늘 자정에 바로 마감입니다🙆🏻‍♀️)
#
# 🏷 구디 이뮨 스틱은 물 없이 맛있게 먹을 수 있는 파우더 타입의 면역력 영양제로
# 평소 꾸준한 영양제 섭취가 어렵거나, 알약을 못드시는 분들,
# 간단하게 먹을 수 있는 영양제가 필요하신 분들께 추천해 드립니다💪🏻
#
# 평소 아연, 셀레늄, 비타민C, 비타민D가 하루 권장량 100%가 포함된
# 멀티 비타민을 잘 드시고 계시다면 굳이 구디 이뮨 스틱을 드시지 않아도 된답니다😚
#
# _
#
# 💊 보통 비타민C,D와 같은 영양소에 대한 중요성은 많이 알고 계셔도
# 미네랄 영양소는 생소한 분들이 계실 거예요🪄
#
# 면역체계에서 아주 중요한 역할을 하고 있는 아연, 셀레늄에 대해 설명해 드릴게요🤍
#
# ✅ 면역력 영양소 중 핵심 미네랄 성분인 [아연]
#
# 아연은 굴이나 소고기, 견과류 섭취를 통해서 얻을 수 있지만
# 사실 매일매일 아연이 함유된 음식을 챙겨먹는게 쉽지 않기 때문에
# 영양제로 꾸준히 섭취하시는 걸 권장해요💪🏻
#
# 👉🏻 아연이 “부족”하면 면역력이 저하되고
# 질병의 발생이나 상처 회복 속도를 더디게 만들며,
# 빈혈 / 감염 / 심혈관계 질환 / 신장 질환 / 알코올 중독 / 스트레스 등을 유발합니다.
#
# 👉🏻 아연이 “결핍”되면 빈번한 감기와 독감 / 지속적인 피로감
# 아이들 성장 및 발달문제 / 급격한 기분 변화
# 학습문제 및 낮은 학업 성취도 / 기억력 감소 / 피부 트러블 / 시력 문제까지 발생할 수 있기 때문에 하루 권장량에 맞추어 섭취해야 하는 정말 중요한 영양소 중 하나입니다.
#
# 💅🏻 특히 손톱에 흰 반점, 흰 가로 줄이 생기거나 손톱 표면이 우글거린다면
# 아연 결핍의 신호이므로 지나치지 말고 꼭 영양제로 챙겨드셔야 해요-
#
# ☕️ 특히 평소에 커피를 많이 드신다면,
# 커피는 음식으로 섭취한 아연의 흡수율을 50% 이상 낮추기 때문에
# 영양제로 꼭 챙겨 드셔야 합니다.
# 구디 이뮨 스틱 또한 커피를 드신 후 2시간 이후에 섭취해 주셔야
# 영양소가 모두 흡수되니 참고해 주세요✨
#
# _
#
# ✅ [셀레늄] 가장 중요한 항산화 영양소로서
# 유해산소로부터 세포를 보호하는데 필요한 미네랄 영양소
#
# 셀레늄이 결핍되면 근력저하, 피로감, 탈모 등이 발생할 수 있으며,
# 👨🏻남성은 정자 운동성이 저하되는 등 남성 불임이 유발될 수 있고
# 🤰🏻임산부의 경우 유산이나 조산, 사산 우려가 있으므로
# 임신 준비 하시는 분들은 부부가 함께 셀레늄을 꾸준히 섭취해 주셔야 합니다.
#
# 🫀또한 셀레늄은 암 예방에 효과가 있다는 연구 결과가 있어요.
# 전립선암 63% / 대장암 58% / 폐암 43% 발생율이 감소되고
# 이 외에 다양한 곳에서 발생하는 암세포의 성장을 억제해준다고 알려져 있습니다.
#
# 일반적으로 비타민E가 항산화 효과가 있다고 알려져 있지만
# 셀레늄은 비타민E보다 항산화 작용의 효과가 약 1,800배 뛰어나서
# 꾸준하게 섭취할 경우 피부에 유해한 대표적 물질인 과산화지질의 생성을 방해하여
# 피부 노화 억제, 피부염, 아토피 등등 각종 피부 질환에 탁월한 효과를 나타낸다고 해요.
#
# 평소 피부 트러블로 고민이신 분들도 구디 이뮨 스틱 꼭! 드셔보세요🍋
#
# 🍚 구디 이뮨 스틱은 식전, 공복에 1포 섭취를 권장하고 있습니다!
# 다만 공복에 드셨을 때 배가 불편하시거나
# 평소 위 불편함을 느끼시는 분들은  비타민이 함유되어 있어 공복에 드실 경우 위를 자극 할 수 있으므로 식후 1포 섭취해 주세요☺️
#
# 🔋평소보다 체력이 더 많이 필요한 날에는 하루 2포까지 섭취가 가능합니다✨
#
# ⏰ 구디 면역력 스틱은 일요일 밤 12시에 마감할게요🫶🏻
# 댓글 수: 14
# 좋아요 수: 비공개
# 미디어 타입: FEED
# 타임스탬프: 2023-06-11T07:04:49+0000
# 사용자명: b.saem
# 사용자 코드: 17841400161289712
# -------------------------------------------------------------------------
# 게시물 ID: 17997936604908027
# 캡션: 팀 베이지크와 1401HOME 팀이 함께한 유기견 봉사 기록📝
#
# 경기도 화성에 있는 RUN 레스큐 도그 파크는
# 유기견들이 해외 입양을 가기 위해 머물고 있는 곳이에요!
# 저도 유기견 봉사는 처음이라서 구디 이뮨으로 한껏 좋아진 체력 불태우고 와야지🔥하는 생각으로 단단히 벼르고 갔는데,
# 막상 견사 청소 외에는 아이들하고 놀아주는 시간이라 힘들지가 않더라구요🙊
# 유기견 봉사 안해보신 분들도 어렵지 않게 하실 수 있을 것 같구요😚
#
# 그나저나 영상에서 아가들 하나같이 다 순둥하고 너무 예쁘죠!
# 근데 하나같이 사연이 다 너무 슬퍼서 마음 아프더라구요
# 도살장에서 죽기 바로 직전에 구출 돼서
# 친구들이 죽는 걸 본 아이들은 아직도 사람을 무서워 하구요 흑흑
#
# 천사같은 아이들 언능 다 좋은 주인 만나길 모두 함께 빌어주세요🪽
#
# 🏷 런 레스큐 도그 파크는 평소에는 두 분이서만 관리하시는 곳이라
# 봉사자분들의 손길이 많이 필요해 보였어요🥹
# 유기견 봉사 생각 있으셨던 분들은 요기 가보시는 거 추천 합니다🤍
#
# 캐나다, 미국 출국하시는 분들은 이동봉사도 가능하니
# 해외 이동봉사도 많이 관심 가져주세요✈️✨
#
# 계정에 봉사 관련 내용 자세히 안내되어 있으니
# 관심있는 분들은 공식 계정에서 확인해 주세요🫶🏻
#
# RUN 레스큐 도그 파크 👉🏻 run_x_care
# 댓글 수: 11
# 좋아요 수: 비공개
# 미디어 타입: FEED
# 타임스탬프: 2023-06-10T05:30:56+0000
# 사용자명: b.saem
# 사용자 코드: 17841400161289712
# -------------------------------------------------------------------------
# 게시물 ID: 18050857447435796
# 캡션: 집에 친구 부부 놀러 오는 날🥂✨
# 친구는 늦어서 미안하다고 하지만 저는 오히려 여유 있어서 좋은 거,,뭔지 아시죠ㅋㅋㅋ
# 오히려 일찍오면 당황스러움😇
#
# 집에 손님 오는 날 이렇게 음식 사진 찍은 거 처음인 것 같구요🙊
# 댓글 수: 17
# 좋아요 수: 549
# 미디어 타입: FEED
# 타임스탬프: 2023-06-07T09:59:02+0000
# 사용자명: b.saem
# 사용자 코드: 17841400161289712
# -------------------------------------------------------------------------
# 게시물 ID: 18062827036401872
# 캡션: 🎪이벤트 있어요🫶🏻
#
# 오래 기다리셨죠🥹
# 드디어 구디 이뮨 스틱이 돌아왔어요🍃
# 더 높아진 함량으로 돌아온 물 없이 털어먹는 상큼한 라즈베리 맛의 구디 이뮨 스틱🍇
#
# 🏷 요즘 피곤해서 골골 대시는 분들 중
# 구디의 이뮨 스틱이 궁금하시다면 댓글로 ”저요!“라고 외쳐주세요🙋🏻‍♀️
# 5분을 뽑아서 1박스(20스틱)을 선물로 보내드릴게요🎁
#
# 이번에 제 여행 스토리 보신 분들은 아실 거예요
# 하루종일 빨빨 거리고 돌아다녔던 제 체력을,,🙈
#
# 아침 7시 부터 일어나서 조식 먹고 골프 라운딩 다녀온 다음에
# 바다 가서 부기보드 타고도 밤 10시까지 밖에서 꽉꽉 채워 논 사람이 저예요,,ㅋㅋㅋ
#
# 체력이 좋아지니깐 여행가서도 정말 많은 걸 할 수 있더라구요🧃
# 좋아진 체력 덕분에 증말 뽕 뽑고 온 이번 하와이는 200% 이뮨 스틱 덕입니다🤍
#
# 물 없이 그냥 털어넣으면 되는 분말 타입이라 간편해서
# 여행지에서도 하루도 빼먹지 않고 먹었어요💫
#
# 📈 구디 이뮨 스틱! 이번에 함량이 더 업그레이드 되었어요!
# 기존 하루 권장 섭취량 비타민 C 280%, 아연 94%, 셀레늄 91% 였던 함량이
# 비타민 C 330%, 아연 118%, 셀레늄 100% 로 높아졌고
# 여기에 비타민D 600IU 까지 더해졌습니다☀️
#
# 💊 다만 기존에 소개해 드렸던 덴프스 비타민D 제품이 4000IU로 하루 상한 섭취량이라,
# 구디 이뮨 스틱과 함께 복용하실 경우 덴프스 비타민D 제품은 이틀에 한번씩만 섭취하시는 걸 권장드려요☺️
#
# ⚠️ 함량 업그레이드가 되면서 비타민D가 추가되어 제형이 살짝 변경되었어요.
# 기존에 미세한 가루 입자였던 제형이 좀 더 굵은 제형으로 변경되고,
# 단 맛이 좀 줄어들어서 기존 제품 드시던 분들은 이전 제품하고 조금 비교가 될 수 있는데요🥺
# 그래도 함량이 더 높아지고 여느 영양제보다는 맛있게 드실 수 있다는 점 참고해 주시면 좋을 것 같아요!
#
# 🪫 점점 피로도가 증가하고 떨어지는 체력이 걱정이셨다면
# 구디 이뮨 스틱 꾸준히 드셔보세요!
# 지난 기획전 때 구매해서 드셔보시고 효과 보신 분들이 많으시답니다🍋
#
# 🔋정말 아무리 강조해도 지나치지 않은 면역력!
# 면역력은 감염과 질병으로부터 우리를 보호하는 체계이기 때문에
# 면역력이 약화되면 감염에 노출되었을 때 각종 질병에 걸릴 확률이 높아아서
# 면역력이 떨어지면 몸 여기저기에서 질병이 발생하기 시작하는데요-
# 질병이 발생한 뒤에 관리하면 원래 컨디션으로 쉽게 돌아오지 않아서
# 건강은 정말 건강할 때 미리미리 챙겨두셔야 고생 안합니다🥹
#
# 제가 항상 강조하는 건건가쉽💪🏻(=건강은 건강할 때 지키는게 가장 쉽다!)
# 구디 이뮨 스틱으로 시작해 보세요✨
#
# 🗓️ 구디 이뮨 스틱은 8일(목요일) 오전 11시에 만나요🫶🏻
#
#  🍋 Goody 이뮨 다이렉트 스틱
#
# ▸ 아연+셀레늄+비타민C,D를 담은 프리미엄 멀티 건기식
# ▸ 국내 최초 L-히스티딘(아미노산) 50mg 함유
# ▸ 체내 흡수가 빠른 파우더 타입
# ▸ 항산화, 세포 보호, 정상적인 면역기능 촉진
# ▸ 독일의 프리미엄 원료와 뛰어난 제조기술을 사용하여 생산
# ▸ 독일 우수건강식품제조기준 및 HACCP, ISO9001 인증 획득
# ▸ 국내 식약처 인증 건강기능식품
# ▸ 부담없는 라즈베리 향으로 상큼달콤한 맛과 청량한 식감
# ▸ 1일 1포 물 없이 맛있는 한포로 간편하게 복용
#
#  👨‍👨‍👧 이런분들께 추천해요
#
# ▸ 만성 피로로 항상 피곤하신 분
# ▸ 활력있는 하루를 원하시는 분
# ▸ 아침에 일어나기가 힘드신분
# ▸ 피부가 거칠거나 건조하신분
# ▸ 손, 발, 몸이 차게 느껴지시는분
# ▸ 항산화 기능성 원료가 필요한분
# ▸ 면역력이 약하거나 정상적인 면역 기능이 필요하신 분
# ▸ 성장기 아이들
# ▸ 식생활이 불규칙한 현대인
# ▸ 임산부, 수유부도 안심하고 먹을 수 있는 비타민을 찾으시는 분
# 댓글 수: 262
# 좋아요 수: 비공개
# 미디어 타입: FEED
# 타임스탬프: 2023-06-06T11:59:40+0000
# 사용자명: b.saem
# 사용자 코드: 17841400161289712
# -------------------------------------------------------------------------
# 게시물 ID: 18004547527669579
# 캡션: 하와이,,사골 끓이는 듕,,,🤍
# 하와이 꿀정보도 곧 정리해서 올릴게요🫡
# 끝나지 않아 하와이,,,
# 댓글 수: 16
# 좋아요 수: 361
# 미디어 타입: REELS
# 타임스탬프: 2023-06-02T13:03:08+0000
# 사용자명: b.saem
# 사용자 코드: 17841400161289712
# -------------------------------------------------------------------------
# 게시물 ID: 18221722009232617
# 캡션: 번들거리지 않고 피부에 촉촉함만 남겨주는 선크림 찾아 헤매던 분들 여기요🤟🏻
# 정말 제가 딱 원했던,,그런 선크림이 어쩜 딱 베이지크 제품인건지,,너무 신기해요🥹
# 저는 제품 개발에 전혀 참여하지 않았지만
# 제가 개발해서 제가 원하는 방향으로 만든 것 마냥ㅋㅋ
# 정말 제 마음에 100% 쏙 드는 선크림이에요🪽
#
# 베이지크 핸드크림 써보신 분들은 아시죠?
# 발랐을 때 피부속으로 싹 흡수돼서 손에 유분 남지 않는 거💫
#
# 베이지크 선스크린이 딱 그런 느낌이에요!
# 특히 피부가 건조하신 분들은 선스크린 바르고 화장하면
# 밀리고 뜨던 화장이 챡! 달라붙는 신세계 경험하실 거랍니다🤍
#
# 발랐을 때 백탁 현상에, 끈적이고 번들거리는 선크림은 이제 안녕👋🏻
# 베이지크가 선크림 신세계 열어드릴게요🕊️
#
# _
#
# ☀️ 자 그리고 베이지크 선스크린의 UVA, UVB 차단
# 항산화 효과, 눈시림 증상 0.00%에 이어서
# 또 엄청난 효능이 하나 있는데요💡
#
# 우리가 깨어있는 시간 중 대부분 마주하고 있는
# 스마트폰, 컴퓨터, TV에서 발생하는 블루라이트📱⚡️
#
# 이 블루라이트가 피부에 노출 되었을 때 멜라닌 색소를 자극시켜서
# 색소 침착은 물론이고 기미와 잡티, 칙칙한 피부를 유발한다는 연구 결과가 있어요.
#
# 지금 이 화면을 보고 있는 이 순간에도 우리 피부는 블루라이트에 노출되고 있는거죠🥺
#
# 하지만 우리 생활과 밀접한 전자기기들을 사용을 안 할 수도 없으니
# 유일한 예방 방법은 블루라이트 차단 효과를 입증받은 선스크린을 사용하는 방법 밖엔 없는데, 시중에 블루라이트까지 차단되는 선크림이 많지는 않더라구요,,
# 근데 이걸 또 베이지크가 합니다,,,🥇
# (출시까지 3년이나 걸린 이유를 알 것 같죠🙊)
#
# ☀️ 베이지크 선스크린은 블루라이트 차단 효과까지 입증 받은 제품이라
# 블루라이트로 부터 우리 피부를 지켜줘요!
#
# 🪞기초 마지막 단계에서 매일 가볍게 바르는 것만으로도
# 피부 노화 방지는 물론, 항산화 효과로 피부결, 피부톤 개선효과까지 있는 베이지크 선스크린!
# 기초 마지막 단계에서 발라주는 습관 들이셔서 우리 남들보다 천천히 늙자구요😚
# 선크림은 하루라도 일찍 바르는 사람이 위너 입니다👑
#
# _
#
# 장점이 너무 많아서 글이 길어질 수 밖에 없는 베이지크 선스크린😚
#
# 미국 해양청에서 고시한 해양 생태계를 파괴할 수 있는 자외선 차단 성분인
# 옥시벤존과 옥티노세이트!
# 하와이를 가보니깐 바다 주변에는 꼭 이 두가지 성분이 포함된 선크림을 금지한다는 표지판이 있더라구요.
#
# 베이지크는 이 두가지 성분은 물론이도 동물성 성분을 일체 배제한 비건 포뮬라로
# 우리 피부는 물론, 환경까지 지킬 수 있는 아주 똑똑한 선 스크린이랍니다✨
#
# _
#
# ☁️ 실내로 투과되는 자외선에도 노출되고 있는 피부!
# 집에 있을 때에도 매일매일 발라주세요.
# 베이지크 선스크린은 묽은 수분 에센스 제형이라 기초 마지막 단계에서 발라주기 딱 좋답니다.
#
# ☁️ 흐린 날에는 안발라도 되겠지?
# 땡! 아니에요❌ 구름이 잔뜩 낀 흐린 날에도 구름이 자외선의 80%를 흡수해서
# 자외선을 내뿜고 있어요.
# 맑은 날, 흐린 날, 비오는 날, 눈 오는 날 가릴 것 없이 자외선 차단제는 사계절 내내 매일매일 발라주셔야 피부 노화를 막을 수 있답니다.
#
# 개인적으로 이번 기획전 때 여유있게 구매하셔서 부모님께도 꼭 선물 드리셨으면 좋겠어요!
# 답답해서 선크림 안바르던 부모님들도 베이지크 선스크린이라면 먼저 찾아서 바르시게 될 거예요🤍🤍🤍
#
# 🪴 베이지크 리바이탈라이징 CE 선스크린
#
# ▸ 자외선 차단 기능성 화장품 SPF 50+ PA++++
# ▸ 실내 블루라이트 차단 (in-vitro 블루라이트 평가 완료)
# ▸ 활성 산소를 케어해주는 항산화 기능성 화장품으로 피부 미용에 도움
# ▸ 촉촉하게 밀착되는 수분 보호막
# ▸ 백탁과 끈적임 없는 산뜻한 에센스 제형
# ▸ 스쿠알란과 그린 커피빈 오일의 수분 포뮬라로 수분 보습
# ▸ 예민해진 피부도 편안하게 진정되는 저자극 비건 포뮬라
# ▸ 쉽게 건조해지는 눈가케어
# ▸ 눈시림 지수 0.00
# ▸ 동물성 성분을 배제하여 피부는 물론이고 해양 환경을 보호
# ▸ 수부지 / 지성 / 건성 / 민감성 / 트러블 피부에게 추천
#
# 🏷 베이지크 기획전은 아직 제가 제대로 설명 못드린 제품들이 있어서
# 일요일까지 연장해서 진행할게요!
# 댓글 수: 10
# 좋아요 수: 비공개
# 미디어 타입: FEED
# 타임스탬프: 2023-06-02T06:14:45+0000
# 사용자명: b.saem
# 사용자 코드: 17841400161289712
# -------------------------------------------------------------------------
# 게시물 ID: 17999338024887567
# 캡션: 🧴 베이지크 헤어듀오는 제작 공장 자체도 일반적인 헤어 제품 만드는 곳이 아니라❌
# 살롱에 납품되는 제품만 제작하는 공장이라 일반적인 홈케어 제품이랑은 효과의 차원이 달라요☝🏻
#
# 실제로 한남동 프리미엄 헤어살롱인 꼼나나비앙에서는 스페셜 헤어 스파 라인 선택시 베이지크 제품으로 관리를 진행할 만큼 살롱에서도 인정받은 프리미엄 홈케어 제품이라서
# 여태까지 사용해 보신 그저 그런 홈케어 제품 생각하시면 안된답니당🤤
#
# 효과가 정말 좋아서 주기적으로 클리닉 받거나 매직을 하셨던 분들도
# 베이지크 헤어듀오 사용 이후에는 미용실을 잘 안가게 되었다는 후기도 정말 많았어요🙊
#
# 🏷 보통 샵에서 1회 클리닉이 기본 10만원 이상인데,
# 헤어 클리닉 많이 받아본 제 경험으로는 1회에 15만원 이상하는 프리미엄 클리닉 정도는 받아야 효과가 있더라구요.
#
# 그리고 모발 클리닉은 모발 위에 영양을 계속 쌓아주는 원리라서
# 머리결 개선을 위해서는 초반에는 2주에 한 번씩 2달 정도 케어 받고 그 다음 한 달 텀으로 꾸준히 받아줘야 그나마 개선되는게 보이더라구요.
#
# 근데 이렇게 클리닉 받으려면 비용+시간 투자를 어마어마하게 해야하는데
# 사실 저희가 뭐 연예인도 아니고,,😇이렇게까지 하기는 힘든게 현실이잖아요-
#
# 클리닉 받으러 가기는 힘든데 머릿결은 좋아지고 싶다! 하시면 베이지크 헤어듀오 꼭 경험해 보세요✨
# 베이지크 헤어듀오 기획전가 68,000원으로 한달~한달 반 정도 사용이 가능하니
# 살롱 클리닉에 비해 정말 훨~~씬 합리적인 금액으로 두피&모발 개선이 가능합니다🧖🏻‍♀️
#
# 근데 사실 경험해 보신 분들은 이미 트리오 세트로 잔뜩 쟁이시고 계세요😇
# 베이지크 제품은 1401HOME 기획전이 가장 저렴하거든요 흐흐
#
# 🦢정가 대비 최대 26%까지 할인 적용되고 있는
# 베이지크 기획전은 금요일 오전 11시 마감이니 늦지않게 막차 타세요🚂💨
#
# 🏷 머리 끝이 많이 상하신 분들은 루센트 오일 함께 구매 하셔서
# 드라이할 때 머리 끝에 발라주시면 효과가 좋아요🫶🏻
# 댓글 수: 31
# 좋아요 수: 418
# 미디어 타입: FEED
# 타임스탬프: 2023-06-01T11:49:29+0000
# 사용자명: b.saem
# 사용자 코드: 17841400161289712
# -------------------------------------------------------------------------
# 게시물 ID: 17991776737842962
# 캡션: 이번에 품목이 너무 많아서 페이셜 라인은 진행하지 않았지만
# 루센트 오일만큼은 포기할 수 없었습니다✨
#
# 저는 수분 부족형 지성인데 루센트 오일 너무 잘 쓰고 있어요🙊
#
# 수부지가 오일을 쓴다?
# 시간 지나면 유분 폭발하는 저로써 얼굴에 오일을 바른 다는 건
# 정말 상상할 수 없는 일이었는데 베이지크 루센트 오일은
# 일반적으로 생각하시는 그런 오일하고는 차원이 달라요😚
#
# 스킨 다음 단계에서 피부결을 따라 발라주면
# 촘촘한 윤광 보습막이 생성되어 꿀피부가 완성되는 매직템🪄
#
# 번들거림 없이 피부 속 수분만 채워주니깐 유수분 밸런스가 맞춰져서
# 루센트 오일 사용한 날에는 유분이 덜 올라오더라구요.
#
# 저 같은 수부지 피부에 좋은 건 물론지고
# 건성분들에게는 이미 너무 유명한 베이지크의 베스트셀러에요🍃
#
# 평소 속건조가 심하거나, 아무리 보습을 해줘도 화장이 뜨는 분들!
# 루센트 오일로 속광을 꽉 채워보세요🦢
#
# 베이지크 루센트 오일은 11가지 식물성 비건 오일이 블렝딘 된 저자극 오일 세럼 텍스처로 산뜻하게 흡수되어 사용할 수록 피부 본연의 보습 능력이 견고해 져서 점점 건강하고 편안해 지는 피부를 경험하실 수 있답니다🪴
#
# 🏷 루센트 오일 활용법
#
# - 핸드크림+루센트 오일로 극강의 보습
# : 손이 심하게 건조하시거나 평소 손을 자주 닦아야 하는 업무에 종사하신 다면
# 핸드크림 바를 때 루센트 오일 2-3방울을 떨어트려서 함께 발라보세요!
# 꽉 찬 보습으로 오랫동안 촉촉한 손으로 가꾸어 줍니다.
# 특히 자기 전에 듬뿍 발라주시면 아침에 촉촉해진 손을 느낄 수 있어요🍯
#
# - 큐티클 라인에 루센트 오일 바르기
# : 베이지크 핸드크림으로도 큐티클 라인 관리가 가능하지만
# 루센트 오일로도 쉽게 큐티클을 깔끔하게 관리할 수 있어요.
# 금방 싸악 흡수되어 번들거리지 않아요☝🏻
# 이렇게 관리해 주시면 굳이 네일샵 가서 큐티클 정리 하지 않으셔도
# 깔끔한 관리가 가능합니다🫶🏻
#
# - 팔꿈치, 발뒷꿈치 관리
# : 여름철 노출되는 팔꿈치, 발뒷꿈치의 각질이 걱정되셨다면
# 루센트 오일로 관리해 주세요!
# 루센트 오일이 거칠어진 팔꿈치, 발뒷꿈치도 보들보들하고 촉촉하게 만들어 드려요🍉
#
# - 갈라진 모발 끝
# : 갈라져서 푸석푸석해 보이는 모발 끝에 발라보세요!
# 기름지지 않고 싸악 흡수됩니다😆
#
# - 바디 마사지용으로 활용
# : 사실 제가 루센트 오일에 확 빠져버린 이유가
# 필라테스 후 종아리 근육이 뭉쳐서 종아리에 루센트 오일을 바르고
# 3일 정도 마사지를 해줬는데 종아리가 갑자기 애기 피부 마냥 보들보들 해진거예요🙊
# 그 이후로 루센트 오일 신봉자가 되었습니다😚
# 평소 운동 후 근육이 뭉친 곳 풀 때 루센트 오일 꼭 사용해 보세요!
#
# 🏷 베이지크 기획전은 내일 오전 11시 마감입니다🍃
# 댓글 수: 5
# 좋아요 수: 비공개
# 미디어 타입: FEED
# 타임스탬프: 2023-06-01T08:17:11+0000
# 사용자명: b.saem
# 사용자 코드: 17841400161289712
# -------------------------------------------------------------------------
# 게시물 ID: 18040659949433492
# 캡션: 하와이 추천 마지막 호텔 할레쿨라니🏝️
# 꼬옥 가보셔야 하는 곳이라 우선 저장하고 보세요💫
#
# 딱 제가 좋아하는 무드의 호텔이라 보자마자 꽂혔던 할레쿨라니✨
# 천국의 집이라는 의미를 가졌다고 하는데 네,,천국 맞더라구요😇
# 일본인이 운영하는 곳이라서 외국인과 일본인이 정말 많았어요!
#
# 위치는 한 블록만 걸어서 나가면 와이키키몰이 있고
# 포케바, 이야스메 무스비, 야드 하우스, 헨리스 플레이스 등
# 유명한 맛집들도 가까운 곳에 있어서
# 그냥 슉슉 나가서 구경하고 밥 먹고 오기도 너무 좋더라구요🫶🏻
#
# 그리고 정말 좋다고 느꼈던 부분 하나가
# 호텔 어딜가나 청소는 매일 해주지만
# 할레쿨라니는 저희가 잠깐 외출 해도 고 잠깐 사이에 들어와서 정리를 해주시더라구요🥹
#
# 사실 여행가면 시간 아까워서 급하게 준비하고 나가기 바쁘다 보니깐
# 룸이 난장판이 되잖아요,,🙊(저만 그런거 아니져,,)
# 근데 이렇게 그때그때 치워주는 서비스에 감동했어요🪽
#
# 그리고 하루에 한번씩 귀여운 할레쿨라니 시그니처 기프트도 주는데
# 요고 모으는 재미도 쏠쏠 합니당😚
#
# 🏊🏻‍♀️ 수영장은 안다즈 마우이 처럼 여러개의 수영장이 있지는 않지만
# 우선 자리가 굉장히 많고, 수영장에서 놀고 있으면 오셔서 쿠키나 아이스크림 같은 간식을 주시더라구요🍦
#
# 🐬 프라이빗 비치는 객실 키가 있어야 들어갈 수 있어요!
#
# 🍳 조식은 종류가 많지는 않지만 맛은 괜찮았어요~!
# 특히 할레쿨라니 앞에 있는 할레쿨라니 베이커리 빵들이 맛있는데,
# 그 빵들을 조식으로 먹을 수 있어서 좋더라구요🙊
# 제가 먹은 빵 중에는 골든 파인애플 데니쉬 맛있었어용🍍
#
# 🍽️ 할레쿨라니 식당으로 유명한 Orchids와
# 재즈바 Lewers lounge도 다녀왔는데 요건 또 따로 피드 남길게요🥂
#
# 🏷 할레쿨라니 하와이
#
# 위치: 와이키키 몰 주변
# 룸 타입: 오션 뷰
#
# ▸ 장점
# - 최고의 인프라, 와이키키몰 도보 3분
# - 쾌적한 룸 상태, 최상의 서비스
# - 태블릿으로 하우스키핑, 식당 예약, 마사지 예약 등 가능
# - 발렛 없이 주차비를 내고 주차 타워에 셀프주차 가능
# (발렛 가능, 발렛비 별도에 차 뺄 때마다 팁을 줘야 해요.)
#
# ▸ 단점
# - 가격,,💸
# - 협소한 프라이빗 비치
# - 프라이빗 비치 이용시 대여 가능한 물품이 적음
# (파라솔, 체어, 구명조끼, 오리발 등은 없고 패들보드, 서핑보드는 렌탈 가능)
#
# 프라이빗 비치는 안다즈 마우이가 너무 좋았어서 그런지
# 이 부분이 조금 비교되기는 했는데 와이키키 비치 자체가 크니깐 크게 문제되지는 않았어요!
# 다만 프라이빗 비치에 파라솔, 체어 등이 없는 건 조금 아쉽더라구요🥲
#
# 그리고 와이키키는 부기보드 탈 정도의 파도는 아니에요!
#
# 🏷 저는 4박 묵었는데, 정말 딱,,딱 5일만 더 묵고 가고 싶은 그런 곳이었어요😭
# 하와이 신행으로 많이 가시던데 요 호텔도 꼭 경험해 보셨으면 좋겠어요🤍
# 댓글 수: 21
# 좋아요 수: 1520
# 미디어 타입: FEED
# 타임스탬프: 2023-06-01T03:38:52+0000
# 사용자명: b.saem
# 사용자 코드: 17841400161289712
# -------------------------------------------------------------------------
# 게시물 ID: 17958462617571076
# 캡션: ①
# 베이지크 이번 기획전에서 9만원 이상 구매시 선물로 드리는
# 정가 28,000원 상당의 베이지크 브리즈 에코백🍃
# 색감 너어무 예쁘지 않나용😚
# 요고 진짜 휘뚤마뚤템이라 여행 내내 얼마나 잘 들고 다녔는지 몰라요✨
#
# 아이패드까지 들어가는 크기라서 이것저것 때려넣기(?) 너무 편해요!
# 이왕 구매하시는 거 9만원 이상 구매하셔서 요 브리즈 에코백 꼭 받아가시구요🤍
# 15만원, 20만원 이상 구매시 사은품도 정말 풍성하게 준비 되어 있으니
# 구매 금액 잘 맞춰서 사은품도 한가득 받아가세요🫶🏻
#
# 🏷 구매 금액대별 사은품은 결제 금액 기준입니다!
#
# ②
# 선스크린 구매 선물 브리즈 파우치(정가 21,000원)✨
# 지난번 기획전 때 선물로 드렸던 파우치도 은근 손 자주 가지 않나요🙊
# 큰 가방에 소지품 넣을 때 덩그러니 넣어서 힘들게 찾지 마시고
# 립, 쿠션 같은 자주 쓰는 화장품은 파우치 안에 넣어서 가방 안에 쏙 넣으시면
# 여기저기 휘집으며 찾을 필요 없이 편해요🤍
#
# 간단한 산책 나갈 때에도 요 파우치 하나 쏙 들고 나가도 편하더라구요 크크
#
# 브리즈 파우치는 선스크린 구매시 주문서당 1개씩 함께 보내드리고 있으니
# 예쁘게 사용해 주세요🍃
# 댓글 수: 17
# 좋아요 수: 비공개
# 미디어 타입: FEED
# 타임스탬프: 2023-05-31T08:55:22+0000
# 사용자명: b.saem
# 사용자 코드: 17841400161289712
# -------------------------------------------------------------------------
# QVFIUklHbjMtR0xsbHFreGRTTnV5bFhCejRDZAVI1S0tUUkZAVUFdhVGw3YjRPdHdRNExGRW5uYnJSN0NFU3VHcEMtUF9id2ZAxdVc0UXRIN1R2enh0YXlNN3ZA3
